# %%
from google.colab import drive
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
# Getting CSV Files
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/predictions_btc_stock.csv')
start_date = datetime(2024,1,30)
# Check the data type of "Unnamed: 0" column
if df["Unnamed: 0"].dtype != np.datetime64:
    try:
        df["Unnamed: 0"] = pd.to_datetime(df["Unnamed: 0"])
    except:
        raise TypeError("Column 'Unnamed: 0' cannot be converted to datetime format.")

# Filter the DataFrame
df_filtered = df[df["Unnamed: 0"] >= start_date]

# Print the filtered DataFrame
print(df_filtered)
plt.figure(figsize=(12, 6))
plt.plot(df_filtered["Unnamed: 0"], df_filtered["Predicted_Close"])



plt.xlabel("Date")
plt.ylabel("Predicted Close Price")

plt.tight_layout()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#     Unnamed: 0  Predicted_Close
# 0   2024-01-30     42099.987937
# 1   2024-01-31     42079.987136
# 2   2024-02-01     42060.052067
# 3   2024-02-02     42040.182515
# 4   2024-02-03     42020.378263
# ..         ...              ...
# 451 2025-04-25     37393.139666
# 452 2025-04-26     37388.607818
# 453 2025-04-27     37384.090864
# 454 2025-04-28     37379.588755
# 455 2025-04-29     37375.101441
#
# [456 rows x 2 columns]
